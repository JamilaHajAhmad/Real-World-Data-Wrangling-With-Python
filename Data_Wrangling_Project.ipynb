# %% [markdown]
# # Real-world Data Wrangling

# %% [markdown]
# In today’s educational landscape, understanding the multifaceted factors influencing student performance is essential.<br> This project explores the relationship between *academic performance* and *mental health*, considering the impact of<br> demographics and parental education.<br> By analyzing the **Students' Performance Factors Dataset** and a **Mental Health API**, the goal is to uncover<br> insights into how mental health conditions and stress levels interact with other factors to shape educational outcomes. <br>*This investigation highlights the importance of addressing mental health as a critical component of student success and well-being.*

# %% [markdown]
# ## 1. Gather data
#
# In this section, we describe the **data sources** used to address the research question and the methods employed to collect them.

# %% [markdown]
# ### **1.1.** Problem Statement

# %% [markdown]
# This project explores the relationship between *academic performance* and *mental health*, aiming to understand how<br> mental health conditions and stress levels impact students' success.<br>
# For data wrangling: **Students' Performance Factors Dataset**, which includes demographic and academic data,<br> and a **Mental Health API**, which provides insights into mental health conditions, stress factors, and coping mechanisms.

# %% [markdown]
# ### **1.2.** Gather at least two datasets using two different data gathering methods
#
# 1. Students' Performance Factors Dataset:<br>
# **Reason of Selection**: it provides detailed information about the crucial factors that affect the academic performance.<br>
#
# 2. Mental Health API:<br>
# **Reason of Selection**: it provides insights into mental health conditions, stress factors, and coping mechanisms.<br>

# %% [markdown]
# #### **Students' Performance Factors Dataset**
#
# Type: *CSV File*
#
# Method: *The data was gathered using the "Download" method from Kaggle source (manually downloaded)*
#
# Why this method?: *Ease of use*
#
# Dataset variables:
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Hours_Studied</td>
#       <td>Number of hours spent studying per week</td>
#     </tr>
#     <tr>
#       <td>Attendance</td>
#       <td>Percentage of classes attended</td>
#     </tr>
#     <tr>
#       <td>Parental_Involvement</td>
#       <td>Level of parental involvement in the student's education (Low, Medium, High)</td>
#     </tr>
#     <tr>
#       <td>Access_to_Resources</td>
#       <td>Availability of educational resources (Low, Medium, High)</td>
#     </tr>
#     <tr>
#       <td>Extracurricular_Activities</td>
#       <td>Participation in extracurricular activities (Yes, No)</td>
#     </tr>
#     <tr>
#       <td>Sleep_Hours</td>
#       <td>Average number of hours of sleep per night</td>
#     </tr>
#     <tr>
#       <td>Previous_Scores</td>
#       <td>Scores from previous exams</td>
#     </tr>
#     <tr>
#       <td>Motivation_Level</td>
#       <td>Student's level of motivation (Low, Medium, High)</td>
#     </tr>
#     <tr>
#       <td>Internet_Access</td>
#       <td>Availability of internet access (Yes, No)</td>
#     </tr>
#     <tr>
#       <td>Tutoring_Sessions</td>
#       <td>Number of tutoring sessions attended per month</td>
#     </tr>
#     <tr>
#       <td>Family_Income</td>
#       <td>Family income level (Low, Medium, High)</td>
#     </tr>
#     <tr>
#       <td>Teacher_Quality</td>
#       <td>Quality of the teachers (Low, Medium, High)</td>
#     </tr>
#     <tr>
#       <td>School_Type</td>
#       <td>Type of school attended (Public, Private)</td>
#     </tr>
#     <tr>
#       <td>Peer_Influence</td>
#       <td>Influence of peers on academic performance (Positive, Neutral, Negative)</td>
#     </tr>
#     <tr>
#       <td>Physical_Activity</td>
#       <td>Average number of hours of physical activity per week</td>
#     </tr>
#     <tr>
#       <td>Learning_Disabilities</td>
#       <td>Presence of learning disabilities (Yes, No)</td>
#     </tr>
#     <tr>
#       <td>Parental_Education_Level</td>
#       <td>Highest education level of parents (High School, College, Postgraduate)</td>
#     </tr>
#     <tr>
#       <td>Distance_from_Home</td>
#       <td>Distance from home to school (Near, Moderate, Far)</td>
#     </tr>
#      <tr>
#       <td>Gender</td>
#       <td>Gender of the student (Male, Female)</td>
#     </tr>
#      <tr>
#       <td>Exam_Score</td>
#       <td>Final exam score</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Importing pandas
import pandas as pd

# Load dataset 1
performance_df = pd.read_csv('./students_performance.csv')

# Get the performance_df
performance_df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %% [markdown]
# #### Mental Health Dataset
#
# Type: *API*
#
# Method: *The data was gathered using the "API" method from Sheety*
#
# Why this method?: *It provides real-time, structured, and customizable access to data*
#
# Dataset variables:
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Timestamp</td>
#       <td>Time the survey was submitted</td>
#     </tr>
#     <tr>
#       <td>Gender</td>
#       <td>Respondent gender (Male, Female)</td>
#     </tr>
#     <tr>
#       <td>Country</td>
#       <td>Respondent country</td>
#     </tr>
#     <tr>
#       <td>Occupation</td>
#       <td>Respondent job, profession, or role that typically involves earning a living or contributing to society.</td>
#     </tr>
#     <tr>
#       <td>self_employed</td>
#       <td>Are you self-employed?</td>
#     </tr>
#     <tr>
#       <td>family_history</td>
#       <td>Do you have a family history of mental illness?</td>
#     </tr>
#     <tr>
#       <td>treatment</td>
#       <td>Have you sought treatment for a mental health condition?</td>
#     </tr>
#     <tr>
#       <td>Days_Indoors</td>
#       <td>How many days have you been indoors?</td>
#     </tr>
#     <tr>
#       <td>Growing_Stress</td>
#       <td>Do you feel growing stress in your life?</td>
#     </tr>
#     <tr>
#       <td>Changes_Habits</td>
#       <td>Do you have changes in your habits or routines?</td>
#     </tr>
#     <tr>
#       <td>Mental_Health_History</td>
#       <td>Do you have mental health history</td>
#     </tr>
#     <tr>
#       <td>Mood_Swings</td>
#       <td>Do you experience mood swings or irregular mood patterns?</td>
#     </tr>
#     <tr>
#       <td>Coping_Struggles</td>
#       <td>Do you have coping struggles or feelings of inadequacy in managing your mental health issues?</td>
#     </tr>
#     <tr>
#       <td>Work_Interest</td>
#       <td>Do you have a work-related interest in mental health, such as therapy, counseling, or support groups?</td>
#     </tr>
#     <tr>
#       <td>Social_Weakness</td>
#       <td>Do you have a social weakness or feelings of being isolated in your social environment?</td>
#     </tr>
#     <tr>
#       <td>mental_health_interview</td>
#       <td>Would you bring up a mental health issue with a potential employer in an interview?</td>
#     </tr>
#     <tr>
#       <td>care_options</td>
#       <td>Do you have any care options available to help manage your mental health issues, such as counseling, therapy, or support groups?</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Importing requests
import requests

# Load dataset 2
mental_health = requests.get('https://api.sheety.co/d11ece2fc0b05e0a19611db02814dcdb/mentalHealth/mentalHealth')

# Raise for Status
mental_health.raise_for_status()

# Get the JSON
mental_health_json = mental_health.json()

# Get the mental_health_df
mental_health_df = pd.DataFrame(mental_health_json['mentalHealth'])
mental_health_df.head()
# Out:
#          timestamp  gender        country occupation selfEmployed  \
# 0  8/27/2014 11:29  Female  United States  Corporate
# 1  8/27/2014 11:31  Female  United States  Corporate
# 2  8/27/2014 11:32  Female  United States  Corporate
# 3  8/27/2014 11:37  Female  United States  Corporate           No
# 4  8/27/2014 11:43  Female  United States  Corporate           No
#
#   familyHistory treatment daysIndoors growingStress changesHabits  \
# 0            No       Yes   1-14 days           Yes            No
# 1           Yes       Yes   1-14 days           Yes            No
# 2           Yes       Yes   1-14 days           Yes            No
# 3           Yes       Yes   1-14 days           Yes            No
# 4           Yes       Yes   1-14 days           Yes            No
#
#   mentalHealthHistory moodSwings copingStruggles workInterest socialWeakness  \
# 0                 Yes     Medium              No           No            Yes
# ...

# %% [markdown]
# ## 2. Assess data
#
# In this section, the datasets are thoroughly evaluated for *quality* and *tidiness* issues that might impact the analysis.<br> This includes checking for **missing**, **duplicate**, or **inconsistent** values, as well as assessing the **structure** to ensure variables<br> are appropriately formatted. The goal is to identify and document potential issues to address during the cleaning process,<br> ensuring the data is reliable and ready for exploration and analysis.

# %% [markdown]
# ### Quality Issue 1:

# %%
# Inspecting the mental_health_df visually using head()
mental_health_df.head()

# Inspecting the mental_health_df visually using sample()
mental_health_df.sample(5)
# Out:
#               timestamp  gender         country occupation selfEmployed  \
# 245682  8/27/2014 12:31    Male   United States  Corporate           No
# 221608   2/21/2015 4:16    Male  United Kingdom  Housewife           No
# 27246   8/27/2014 13:31  Female          Canada     Others           No
# 124452  2/21/2015 17:19    Male     Netherlands   Business           No
# 179626  8/28/2014 17:02    Male   United States  Housewife           No
#
#        familyHistory treatment         daysIndoors growingStress  \
# 245682            No       Yes          31-60 days         Maybe
# 221608            No        No  More than 2 months            No
# 27246            Yes       Yes           1-14 days            No
# 124452            No        No    Go out Every day            No
# 179626            No        No          31-60 days            No
#
#        changesHabits mentalHealthHistory moodSwings copingStruggles  \
# 245682           Yes                  No     Medium              No
# ...

# %%
# Inspecting the mental_health_df programmatically
mental_health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292364 entries, 0 to 292363
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   timestamp              292364 non-null  object
#  1   gender                 292364 non-null  object
#  2   country                292364 non-null  object
#  3   occupation             292364 non-null  object
#  4   selfEmployed           292364 non-null  object
#  5   familyHistory          292364 non-null  object
#  6   treatment              292364 non-null  object
#  7   daysIndoors            292364 non-null  object
#  8   growingStress          292364 non-null  object
#  9   changesHabits          292364 non-null  object
#  10  mentalHealthHistory    292364 non-null  object
#  11  moodSwings             292364 non-null  object
#  12  copingStruggles        292364 non-null  object
#  13  workInterest           292364 non-null  object
# ...

# %% [markdown]
# Issue and justification:
# The issue with the selfEmployed column comes from how missing values are represented in the dataset.<br> The info() method only reports missing values as NaN (Not a Number) or None in pandas, but sometimes missing data is represented in alternative ways,such as:
#
# **Placeholder Values**: Missing values could be represented by strings like 'NA', 'N/A', 'Unknown', 'None', or other similar placeholders<br> that pandas doesn't recognize as null automatically.
#
# **Whitespace**: Missing entries could be represented by empty strings ('' or ' '), which info() does not interpret as missing.<br>
# So I've to solve this and get back to the main issue.

# %%
# Using unique() to know the representation of null values 
mental_health_df['selfEmployed'].unique()

# Replacing null values with NAN
import numpy as np
missing_values = [''] 
mental_health_df['selfEmployed'] = mental_health_df['selfEmployed'].replace(missing_values, np.nan)

# Rechecking the unique values of selfEmployed
mental_health_df['selfEmployed'].unique()

# Re-inspecting the mental_health_df programmatically
mental_health_df.head()
# Out:
#          timestamp  gender        country occupation selfEmployed  \
# 0  8/27/2014 11:29  Female  United States  Corporate          NaN
# 1  8/27/2014 11:31  Female  United States  Corporate          NaN
# 2  8/27/2014 11:32  Female  United States  Corporate          NaN
# 3  8/27/2014 11:37  Female  United States  Corporate           No
# 4  8/27/2014 11:43  Female  United States  Corporate           No
#
#   familyHistory treatment daysIndoors growingStress changesHabits  \
# 0            No       Yes   1-14 days           Yes            No
# 1           Yes       Yes   1-14 days           Yes            No
# 2           Yes       Yes   1-14 days           Yes            No
# 3           Yes       Yes   1-14 days           Yes            No
# 4           Yes       Yes   1-14 days           Yes            No
#
#   mentalHealthHistory moodSwings copingStruggles workInterest socialWeakness  \
# 0                 Yes     Medium              No           No            Yes
# ...

# %% [markdown]
# Now, after the missing values representation issue was solved, we can now justify the main issue.

# %%
# Inspecting the mental_health_df programmatically
mental_health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292364 entries, 0 to 292363
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   timestamp              292364 non-null  object
#  1   gender                 292364 non-null  object
#  2   country                292364 non-null  object
#  3   occupation             292364 non-null  object
#  4   selfEmployed           287162 non-null  object
#  5   familyHistory          292364 non-null  object
#  6   treatment              292364 non-null  object
#  7   daysIndoors            292364 non-null  object
#  8   growingStress          292364 non-null  object
#  9   changesHabits          292364 non-null  object
#  10  mentalHealthHistory    292364 non-null  object
#  11  moodSwings             292364 non-null  object
#  12  copingStruggles        292364 non-null  object
#  13  workInterest           292364 non-null  object
# ...

# %% [markdown]
# The *quality issue* here is **completeness**, as we can see there are missing values in *selfEmployed* column.

# %% [markdown]
# ### Quality Issue 2:

# %%
# Inspecting the performance_df visually
performance_df.head(10)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
# 5             19          88               Medium              Medium
# 6             29          84               Medium                 Low
# 7             25          78                  Low                High
# 8             17          94               Medium                High
# 9             23          98               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# ...

# %%
# Inspecting the performance_df programmatically
performance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %% [markdown]
# Issue and justification:
# As we can see, there is a **Completeness** *quality issue* with Teacher_Quality, Parental_Education_Level and<br>
# Distance_from_Home columns (they have missing values).<br>

# %% [markdown]
# ### Tidiness Issue 1:

# %%
# Inspecting the mental_health_df visually
mental_health_df.sample(10, random_state=2)
# Out:
#               timestamp  gender         country occupation selfEmployed  \
# 116562  8/27/2014 12:42    Male   United States  Corporate           No
# 75767    8/29/2014 9:23    Male  United Kingdom  Corporate           No
# 188689  8/27/2014 17:39    Male  United Kingdom    Student           No
# 264375  8/27/2014 23:30    Male       Australia    Student           No
# 140419   9/8/2014 16:46    Male        Colombia   Business           No
# 57912    8/29/2014 3:08    Male   United States    Student           No
# 133332  8/27/2014 17:03    Male   United States   Business           No
# 264742  8/27/2014 12:22    Male   United States   Business           No
# 211200  8/27/2014 11:38    Male   United States     Others          Yes
# 45712   8/29/2014 10:06  Female   United States    Student           No
#
#        familyHistory treatment         daysIndoors growingStress  \
# 116562           Yes       Yes  More than 2 months           Yes
# ...

# %%
# Inspecting the mental_health_df programmatically using nunique() 
mental_health_df.nunique()
# Out:
# timestamp                   580
# gender                        2
# country                      35
# occupation                    5
# selfEmployed                  2
# familyHistory                 2
# treatment                     2
# daysIndoors                   5
# growingStress                 3
# changesHabits                 3
# mentalHealthHistory           3
# moodSwings                    3
# copingStruggles               2
# workInterest                  3
# socialWeakness                3
# mentalHealthInterview         3
# careOptions                   3
# id                       292364
# dtype: int64

# %% [markdown]
# Issue and justification:
#
# Multiple Observational Units in a Single Table:<br>
#
# According to the principles of tidy data, each type of observational unit should form a separate table.
#
# In this case, the table should be split into two separate tables, one for person details and one for mental health details.

# %% [markdown]
# ### Tidiness Issue 2:

# %% [markdown]
# I'm gonna use another student performance dataset to figure out another tidiness issue since there is no one in the previous
# one.

# %%
# Get the dataset from the csv file
new_performance_df = pd.read_csv('./student-performance.csv', sep=';')

# %%
# Inspecting the performance_df visually using head() for ease of use
new_performance_df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# ...

# %%
# Inspecting the performance_df programmatically using describe() for detailed information
new_performance_df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %% [markdown]
# Issue and justification:
#
# Multiple Observational Units in a Single Table:<br>
#
# Looking at the table, there are some columns that are related to student not his/her performance.<br>
#
# This could be seen as mixing two types of observational units: individual student and the his/her performance.

# %% [markdown]
# ## 3. Clean data
# In this section, we discuss the steps taken to clean and prepare the data for analysis.<br> Cleaning the data is an essential part of any data science project, as raw data often contains errors, inconsistencies, and irrelevant information.<br> The goal of data cleaning is to ensure that the data is tidy, accurate, and formatted correctly for analysis.

# %%
# Make copies of the datasets to ensure the raw dataFrames are not impacted
clean_performance_df = performance_df.copy()
clean_mental_health_df = mental_health_df.copy()
clean_new_performance_df = new_performance_df.copy()

# %% [markdown]
# ### **Quality Issue 1:**

# %%
# Apply the cleaning strategy
clean_mental_health_df['selfEmployed'].fillna('Unknown', inplace=True)

# %%
# Validate the cleaning was successful
clean_mental_health_df.head()
# Out:
#          timestamp  gender        country occupation selfEmployed  \
# 0  8/27/2014 11:29  Female  United States  Corporate      Unknown
# 1  8/27/2014 11:31  Female  United States  Corporate      Unknown
# 2  8/27/2014 11:32  Female  United States  Corporate      Unknown
# 3  8/27/2014 11:37  Female  United States  Corporate           No
# 4  8/27/2014 11:43  Female  United States  Corporate           No
#
#   familyHistory treatment daysIndoors growingStress changesHabits  \
# 0            No       Yes   1-14 days           Yes            No
# 1           Yes       Yes   1-14 days           Yes            No
# 2           Yes       Yes   1-14 days           Yes            No
# 3           Yes       Yes   1-14 days           Yes            No
# 4           Yes       Yes   1-14 days           Yes            No
#
#   mentalHealthHistory moodSwings copingStruggles workInterest socialWeakness  \
# 0                 Yes     Medium              No           No            Yes
# ...

# %% [markdown]
# Justification:
#
# I feel that the missing values are significant and should not be replaced with the most frequent category.<br>
# This approach acknowledges that the missing data might carry some meaning, and it allows to retain the<br> distinction between missing and known values, which could be useful for later analysis.

# %% [markdown]
# ### **Quality Issue 2:**

# %%
# Apply the cleaning strategy
teacher_quality_mode = clean_performance_df['Teacher_Quality'].mode()[0]
parental_education_mode = clean_performance_df['Parental_Education_Level'].mode()[0]
distance_from_home_mode = clean_performance_df['Distance_from_Home'].mode()[0]
clean_performance_df['Teacher_Quality'].fillna(teacher_quality_mode, inplace=True)
clean_performance_df['Parental_Education_Level'].fillna(parental_education_mode, inplace=True)
clean_performance_df['Distance_from_Home'].fillna(distance_from_home_mode, inplace=True)

# %%
# Validate the cleaning was successful
print(sum(clean_performance_df['Teacher_Quality'].isnull()))
print(sum(clean_performance_df['Parental_Education_Level'].isnull()))
print(sum(clean_performance_df['Distance_from_Home'].isnull()))
clean_performance_df.info()
# Out:
# 0
# 0
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6607 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %% [markdown]
# Justification:
# I chose to fill the missing values with the mode of the respective column, as this approach is generally considered a good strategy for dealing with categorical variables.<br>
# This approach maintains the integrity of the data and allows for meaningful analysis.

# %% [markdown]
# ### **Tidiness Issue 1:**

# %%
# Apply the cleaning strategy
person_df = mental_health_df[['id','timestamp','gender','country','occupation','selfEmployed']]
clean_mental_health_df = mental_health_df[['id','occupation','familyHistory','treatment','daysIndoors','growingStress','changesHabits','mentalHealthHistory','moodSwings','copingStruggles','workInterest','socialWeakness','mentalHealthInterview','careOptions']]

# %%
# Setting the id to be the index
person_df.set_index('id', inplace=True)
clean_mental_health_df.set_index('id', inplace=True)

# %%
# Get a clean_mental_heath_df for students only
clean_mental_health_df = clean_mental_health_df.query('occupation == "Student"')

# Drop the occupation column as it is not needed anymore (since it is already present in the person_df)
clean_mental_health_df.drop('occupation', inplace=True, axis=1)

# %%
# Validate the cleaning was successful
clean_mental_health_df.sample(10)
# Out:
#        familyHistory treatment         daysIndoors growingStress  \
# id
# 247189            No       Yes    Go out Every day           Yes
# 121146           Yes       Yes          31-60 days            No
# 162022            No        No    Go out Every day         Maybe
# 49476            Yes       Yes          31-60 days         Maybe
# 109038            No       Yes           1-14 days         Maybe
# 78947            Yes       Yes    Go out Every day           Yes
# 245070            No        No          15-30 days           Yes
# 180450            No        No          31-60 days           Yes
# 233676           Yes        No  More than 2 months         Maybe
# 2651              No       Yes    Go out Every day         Maybe
#
#        changesHabits mentalHealthHistory moodSwings copingStruggles  \
# id
# 247189           Yes                  No     Medium              No
# 121146         Maybe               Maybe       High              No
# ...

# %% [markdown]
# Justification:
#
# By splitting the tables, we maintain clear boundaries between person-related data and mentalHealth-related data, adhering to the tidy data principle: each type of observational unit should form a table.

# %% [markdown]
# ### **Tidiness Issue 2:**

# %%
# Apply the cleaning strategy
clean_student_df = clean_new_performance_df[['school','sex','age','address','famsize']]
clean_student_performance_df = clean_new_performance_df[
    ['Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures',
    'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime',
    'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']]

# %%
# Validate the cleaning was successful
clean_student_df.sample(5)
clean_student_performance_df.head()
# Out:
#   Pstatus  Medu  Fedu     Mjob      Fjob  reason guardian  traveltime  \
# 0       A     4     4  at_home   teacher  course   mother           2
# 1       T     1     1  at_home     other  course   father           1
# 2       T     1     1  at_home     other   other   mother           1
# 3       T     4     2   health  services    home   mother           1
# 4       T     3     3    other     other    home   father           1
#
#    studytime  failures  ... famrel freetime goout Dalc Walc health absences  \
# 0          2         0  ...      4        3     4    1    1      3        4
# 1          2         0  ...      5        3     3    1    1      3        2
# 2          2         0  ...      4        3     2    2    3      3        6
# 3          3         0  ...      3        2     2    1    1      5        0
# 4          2         0  ...      4        3     2    1    2      5        0
#
#    G1  G2  G3
# 0   0  11  11
# 1   9  11  11
# 2  12  13  12
# 3  14  14  14
# ...

# %% [markdown]
# Justification:
#
# By splitting the tables, we maintain clear boundaries between student-related data and performance-related data, adhering to the tidy data principle: each type of observational unit should form a table.

# %% [markdown]
# ### **Remove unnecessary variables and combine datasets**

# %%
# Remove unnecessary variables 
clean_student_performance_df = clean_student_performance_df.drop(['School_Type', 'Peer_Influence', 'Internet_Access'], axis=1)
clean_mental_health_df = clean_mental_health_df.drop(['timestamp', 'occupation'], axis=1)

# %%
# Combine datasets
combined_df = pd.concat([clean_student_performance_df, clean_mental_health_df], axis=0, ignore_index=True)

# %%
# Check results
clean_student_performance_df.head()
clean_mental_health_df.sample()
# Out:
#        gender        country selfEmployed mental_health_variable response
# id
# 150428   Male  United States           No         socialWeakness       No

# %% [markdown]
# ## 4. Update data store
# Update the local database/data store with the cleaned data, following best practices for storing the cleaned data:
#
# - Must maintain different instances / versions of data (raw and cleaned data)
# - Must name the dataset files informatively
# - Ensure both the raw and cleaned data is saved to your database/data store

# %%
# saving data
# Note that the raw performance dataset is already in the folder, we just need to save the raw mental_health_df
clean_student_performance_df.to_csv('./clean_student_performance.csv', index=False)
mental_health_df.to_csv('./mental_health.csv', index=False)
clean_mental_health_df.to_csv('./clean_students_mental_health.csv', index=False)

# %% [markdown]
# ## 5. Answer the research question
#
# ### **5.1:** Define and answer the research question

# %% [markdown]
# *Research question:*
#     How do numerical performance metrics (attendance, hours studied, exam score) vary among male and female students, and how are these metrics correlated?

# %%
# Visual 1

import matplotlib.pyplot as plt

clean_student_performance_df.hist(column=['Attendance', 'Hours_Studied', 'Exam_Score'], 
                                by='Gender', 
                                figsize=(10, 8), 
                                bins=10, 
                                layout=(3, 2), 
                                sharex=False, 
                                sharey=False,
                                legend=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Answer to research question:*
#
# *Attendance*: Both genders have similar attendance distributions, with most students in the middle range.
#
# *Hours Studied*: Females slightly dominate lower study hours, while males appear more evenly distributed.
#
# *Exam Scores*: Males and females show comparable peaks around the mid-range, with slightly higher male variability.

# %%
# Visual 2

# Plot the pie chart for each column by 'Gender'
clean_student_performance_df.groupby('Gender')[['Attendance', 'Hours_Studied', 'Exam_Score']]\
    .sum()\
    .plot.pie(subplots=True, figsize=(11, 9), autopct='%1.1f%%', legend=True, startangle=90, labels=['F','M'])
plt.show()

# %% [markdown]
# *Answer to research question:*
#
# For Attendance, Hours_Studied, and Exam_Score, the distribution of males and females appears to be almost equal, with males representing about 57.8% and females 42.2% for each category.
#
# There is a consistent trend across all three charts where males (M) have a slightly higher percentage than females (F) in all categories: Attendance, Hours Studied, and Exam Score.

# %% [markdown]
# ### Conclusion
#
# Based on the current data shown by these pie charts and histograms, gender does not seem to have a significant effect on the student's performance (in terms of attendance, hours studied, and exam score) when considering their mental health outcomes.
#
# However, more in-depth analysis, such as looking at correlations or further statistical testing, would be required for a deeper understanding.

# %% [markdown]
# ### **5.2:** Reflection

# %% [markdown]
# If I had more time, I would further explore the missing values and data inconsistencies, especially in columns related to mental health and performance, to improve the accuracy and completeness of the dataset.
